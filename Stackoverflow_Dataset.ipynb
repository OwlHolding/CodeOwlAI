# %%
import pandas as pd
import numpy as np

# %%
# !echo "deb https://packages.cloud.google.com/apt cloud-sdk main" | sudo tee -a /etc/apt/sources.list.d/google-cloud-sdk.list
# Out:
# deb https://packages.cloud.google.com/apt cloud-sdk main

# %%
# !sudo apt-get install apt-transport-https ca-certificates gnupg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ca-certificates is already the newest version (20210119~18.04.1).
# gnupg is already the newest version (2.2.4-1ubuntu1.4).
# gnupg set to manually installed.
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 4,348 B of archives.
# After this operation, 154 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 apt-transport-https all 1.6.14 [4,348 B]
# Fetched 4,348 B in 0s (12.3 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# ...

# %%
# !gsutil -m cp \
  "gs://stack-overflow228/answers-000000000000.csv" \
  "gs://stack-overflow228/answers-000000000001.csv" \
  "gs://stack-overflow228/answers-000000000002.csv" \
  "gs://stack-overflow228/answers-000000000003.csv" \
  "gs://stack-overflow228/answers-000000000004.csv" \
  "gs://stack-overflow228/answers-000000000005.csv" \
  "gs://stack-overflow228/answers-000000000006.csv" \
  "gs://stack-overflow228/answers-000000000007.csv" \
  "gs://stack-overflow228/answers-000000000008.csv" \
  "gs://stack-overflow228/answers-000000000009.csv" \
  "gs://stack-overflow228/answers-000000000010.csv" \
  "gs://stack-overflow228/answers-000000000011.csv" \
  "gs://stack-overflow228/answers-000000000012.csv" \
  "gs://stack-overflow228/answers-000000000013.csv" \
  "gs://stack-overflow228/answers-000000000014.csv" \
  "gs://stack-overflow228/answers-000000000015.csv" \
  "gs://stack-overflow228/answers-000000000016.csv" \
  "gs://stack-overflow228/answers-000000000017.csv" \
  "gs://stack-overflow228/answers-000000000018.csv" \
  "gs://stack-overflow228/answers-000000000019.csv" \
  "gs://stack-overflow228/answers-000000000020.csv" \
  "gs://stack-overflow228/answers-000000000021.csv" \
  "gs://stack-overflow228/answers-000000000022.csv" \
  "gs://stack-overflow228/answers-000000000023.csv" \
  "gs://stack-overflow228/answers-000000000024.csv" \
  "gs://stack-overflow228/answers-000000000025.csv" \
  "gs://stack-overflow228/answers-000000000026.csv" \
  "gs://stack-overflow228/answers-000000000027.csv" \
  "gs://stack-overflow228/answers-000000000028.csv" \
  "gs://stack-overflow228/answers-000000000029.csv" \
  "gs://stack-overflow228/answers-000000000030.csv" \
  "gs://stack-overflow228/answers-000000000031.csv" \
  "gs://stack-overflow228/answers-000000000032.csv" \
  "gs://stack-overflow228/answers-000000000033.csv" \
  "gs://stack-overflow228/answers-000000000034.csv" \
  "gs://stack-overflow228/answers-000000000035.csv" \
  "gs://stack-overflow228/answers-000000000036.csv" \
  "gs://stack-overflow228/answers-000000000037.csv" \
  "gs://stack-overflow228/answers-000000000038.csv" \
  "gs://stack-overflow228/answers-000000000039.csv" \
  "gs://stack-overflow228/answers-000000000040.csv" \
  "gs://stack-overflow228/answers-000000000041.csv" \
  "gs://stack-overflow228/answers-000000000042.csv" \
  "gs://stack-overflow228/answers-000000000043.csv" \
  "gs://stack-overflow228/answers-000000000044.csv" \
  "gs://stack-overflow228/answers-000000000045.csv" \
  "gs://stack-overflow228/answers-000000000046.csv" \
  "gs://stack-overflow228/answers-000000000047.csv" \
  "gs://stack-overflow228/answers-000000000048.csv" \
  "gs://stack-overflow228/answers-000000000049.csv" \
  "gs://stack-overflow228/answers-000000000050.csv" \
  "gs://stack-overflow228/answers-000000000051.csv" \
  "gs://stack-overflow228/answers-000000000052.csv" \
  "gs://stack-overflow228/answers-000000000053.csv" \
  "gs://stack-overflow228/answers-000000000054.csv" \
  "gs://stack-overflow228/answers-000000000055.csv" \
  "gs://stack-overflow228/answers-000000000056.csv" \
  "gs://stack-overflow228/answers-000000000057.csv" \
  "gs://stack-overflow228/answers-000000000058.csv" \
  "gs://stack-overflow228/answers-000000000059.csv" \
  "gs://stack-overflow228/answers-000000000060.csv" \
  "gs://stack-overflow228/answers-000000000061.csv" \
  "gs://stack-overflow228/answers-000000000062.csv" \
  "gs://stack-overflow228/answers-000000000063.csv" \
  "gs://stack-overflow228/answers-000000000064.csv" \
  "gs://stack-overflow228/answers-000000000065.csv" \
  "gs://stack-overflow228/answers-000000000066.csv" \
  "gs://stack-overflow228/answers-000000000067.csv" \
  "gs://stack-overflow228/answers-000000000068.csv" \
  "gs://stack-overflow228/answers-000000000069.csv" \
  "gs://stack-overflow228/answers-000000000070.csv" \
  "gs://stack-overflow228/answers-000000000071.csv" \
  "gs://stack-overflow228/answers-000000000072.csv" \
  "gs://stack-overflow228/answers-000000000073.csv" \
  "gs://stack-overflow228/answers-000000000074.csv" \
  "gs://stack-overflow228/answers-000000000075.csv" \
  "gs://stack-overflow228/answers-000000000076.csv" \
  "gs://stack-overflow228/answers-000000000077.csv" \
  "gs://stack-overflow228/answers-000000000078.csv" \
  "gs://stack-overflow228/answers-000000000079.csv" \
  "gs://stack-overflow228/answers-000000000080.csv" \
  "gs://stack-overflow228/answers-000000000081.csv" \
  "gs://stack-overflow228/answers-000000000082.csv" \
  "gs://stack-overflow228/answers-000000000083.csv" \
  "gs://stack-overflow228/answers-000000000084.csv" \
  "gs://stack-overflow228/answers-000000000085.csv" \
  "gs://stack-overflow228/answers-000000000086.csv" \
  "gs://stack-overflow228/answers-000000000087.csv" \
  "gs://stack-overflow228/answers-000000000088.csv" \
  "gs://stack-overflow228/answers-000000000089.csv" \
  "gs://stack-overflow228/answers-000000000090.csv" \
  "gs://stack-overflow228/answers-000000000091.csv" \
  "gs://stack-overflow228/answers-000000000092.csv" \
  "gs://stack-overflow228/answers-000000000093.csv" \
  "gs://stack-overflow228/answers-000000000094.csv" \
  "gs://stack-overflow228/answers-000000000095.csv" \
  "gs://stack-overflow228/answers-000000000096.csv" \
  "gs://stack-overflow228/answers-000000000097.csv" \
  "gs://stack-overflow228/answers-000000000098.csv" \
  "gs://stack-overflow228/answers-000000000099.csv" \
  .
# Out:
# Copying gs://stack-overflow228/answers-000000000000.csv...
# Copying gs://stack-overflow228/answers-000000000001.csv...
# Copying gs://stack-overflow228/answers-000000000002.csv...
# Copying gs://stack-overflow228/answers-000000000003.csv...
# Copying gs://stack-overflow228/answers-000000000004.csv...
# Copying gs://stack-overflow228/answers-000000000005.csv...
# Copying gs://stack-overflow228/answers-000000000006.csv...
# Copying gs://stack-overflow228/answers-000000000007.csv...
# Copying gs://stack-overflow228/answers-000000000008.csv...
# Copying gs://stack-overflow228/answers-000000000009.csv...
# Copying gs://stack-overflow228/answers-000000000010.csv...
# Copying gs://stack-overflow228/answers-000000000011.csv...
# Copying gs://stack-overflow228/answers-000000000012.csv...
# Copying gs://stack-overflow228/answers-000000000013.csv...
# Copying gs://stack-overflow228/answers-000000000014.csv...
# Copying gs://stack-overflow228/answers-000000000015.csv...
# ...

# %%
# !gsutil -m cp \
  "gs://stack-overflow228/answers-000000000100.csv" \
  "gs://stack-overflow228/answers-000000000101.csv" \
  "gs://stack-overflow228/answers-000000000102.csv" \
  "gs://stack-overflow228/answers-000000000103.csv" \
  "gs://stack-overflow228/answers-000000000104.csv" \
  "gs://stack-overflow228/answers-000000000105.csv" \
  "gs://stack-overflow228/answers-000000000106.csv" \
  "gs://stack-overflow228/answers-000000000107.csv" \
  "gs://stack-overflow228/answers-000000000108.csv" \
  "gs://stack-overflow228/answers-000000000109.csv" \
  "gs://stack-overflow228/answers-000000000110.csv" \
  "gs://stack-overflow228/answers-000000000111.csv" \
  "gs://stack-overflow228/questions-000000000000.csv" \
  "gs://stack-overflow228/questions-000000000001.csv" \
  "gs://stack-overflow228/questions-000000000002.csv" \
  "gs://stack-overflow228/questions-000000000003.csv" \
  "gs://stack-overflow228/questions-000000000004.csv" \
  "gs://stack-overflow228/questions-000000000005.csv" \
  "gs://stack-overflow228/questions-000000000006.csv" \
  "gs://stack-overflow228/questions-000000000007.csv" \
  "gs://stack-overflow228/questions-000000000008.csv" \
  "gs://stack-overflow228/questions-000000000009.csv" \
  "gs://stack-overflow228/questions-000000000010.csv" \
  "gs://stack-overflow228/questions-000000000011.csv" \
  "gs://stack-overflow228/questions-000000000012.csv" \
  "gs://stack-overflow228/questions-000000000013.csv" \
  "gs://stack-overflow228/questions-000000000014.csv" \
  "gs://stack-overflow228/questions-000000000015.csv" \
  "gs://stack-overflow228/questions-000000000016.csv" \
  "gs://stack-overflow228/questions-000000000017.csv" \
  "gs://stack-overflow228/questions-000000000018.csv" \
  "gs://stack-overflow228/questions-000000000019.csv" \
  "gs://stack-overflow228/questions-000000000020.csv" \
  "gs://stack-overflow228/questions-000000000021.csv" \
  "gs://stack-overflow228/questions-000000000022.csv" \
  "gs://stack-overflow228/questions-000000000023.csv" \
  "gs://stack-overflow228/questions-000000000024.csv" \
  "gs://stack-overflow228/questions-000000000025.csv" \
  "gs://stack-overflow228/questions-000000000026.csv" \
  "gs://stack-overflow228/questions-000000000027.csv" \
  "gs://stack-overflow228/questions-000000000028.csv" \
  "gs://stack-overflow228/questions-000000000029.csv" \
  "gs://stack-overflow228/questions-000000000030.csv" \
  "gs://stack-overflow228/questions-000000000031.csv" \
  "gs://stack-overflow228/questions-000000000032.csv" \
  "gs://stack-overflow228/questions-000000000033.csv" \
  "gs://stack-overflow228/questions-000000000034.csv" \
  "gs://stack-overflow228/questions-000000000035.csv" \
  "gs://stack-overflow228/questions-000000000036.csv" \
  "gs://stack-overflow228/questions-000000000037.csv" \
  "gs://stack-overflow228/questions-000000000038.csv" \
  "gs://stack-overflow228/questions-000000000039.csv" \
  "gs://stack-overflow228/questions-000000000040.csv" \
  "gs://stack-overflow228/questions-000000000041.csv" \
  "gs://stack-overflow228/questions-000000000042.csv" \
  "gs://stack-overflow228/questions-000000000043.csv" \
  "gs://stack-overflow228/questions-000000000044.csv" \
  "gs://stack-overflow228/questions-000000000045.csv" \
  "gs://stack-overflow228/questions-000000000046.csv" \
  "gs://stack-overflow228/questions-000000000047.csv" \
  "gs://stack-overflow228/questions-000000000048.csv" \
  "gs://stack-overflow228/questions-000000000049.csv" \
  "gs://stack-overflow228/questions-000000000050.csv" \
  "gs://stack-overflow228/questions-000000000051.csv" \
  "gs://stack-overflow228/questions-000000000052.csv" \
  "gs://stack-overflow228/questions-000000000053.csv" \
  "gs://stack-overflow228/questions-000000000054.csv" \
  "gs://stack-overflow228/questions-000000000055.csv" \
  "gs://stack-overflow228/questions-000000000056.csv" \
  "gs://stack-overflow228/questions-000000000057.csv" \
  "gs://stack-overflow228/questions-000000000058.csv" \
  "gs://stack-overflow228/questions-000000000059.csv" \
  "gs://stack-overflow228/questions-000000000060.csv" \
  "gs://stack-overflow228/questions-000000000061.csv" \
  "gs://stack-overflow228/questions-000000000062.csv" \
  "gs://stack-overflow228/questions-000000000063.csv" \
  "gs://stack-overflow228/questions-000000000064.csv" \
  "gs://stack-overflow228/questions-000000000065.csv" \
  "gs://stack-overflow228/questions-000000000066.csv" \
  "gs://stack-overflow228/questions-000000000067.csv" \
  "gs://stack-overflow228/questions-000000000068.csv" \
  "gs://stack-overflow228/questions-000000000069.csv" \
  "gs://stack-overflow228/questions-000000000070.csv" \
  "gs://stack-overflow228/questions-000000000071.csv" \
  "gs://stack-overflow228/questions-000000000072.csv" \
  "gs://stack-overflow228/questions-000000000073.csv" \
  "gs://stack-overflow228/questions-000000000074.csv" \
  "gs://stack-overflow228/questions-000000000075.csv" \
  "gs://stack-overflow228/questions-000000000076.csv" \
  "gs://stack-overflow228/questions-000000000077.csv" \
  "gs://stack-overflow228/questions-000000000078.csv" \
  "gs://stack-overflow228/questions-000000000079.csv" \
  "gs://stack-overflow228/questions-000000000080.csv" \
  "gs://stack-overflow228/questions-000000000081.csv" \
  "gs://stack-overflow228/questions-000000000082.csv" \
  "gs://stack-overflow228/questions-000000000083.csv" \
  "gs://stack-overflow228/questions-000000000084.csv" \
  "gs://stack-overflow228/questions-000000000085.csv" \
  "gs://stack-overflow228/questions-000000000086.csv" \
  "gs://stack-overflow228/questions-000000000087.csv" \
  .
# Out:
# Copying gs://stack-overflow228/answers-000000000100.csv...
# Copying gs://stack-overflow228/answers-000000000101.csv...
# Copying gs://stack-overflow228/answers-000000000102.csv...
# Copying gs://stack-overflow228/answers-000000000103.csv...
# Copying gs://stack-overflow228/answers-000000000104.csv...
# Copying gs://stack-overflow228/answers-000000000105.csv...
# Copying gs://stack-overflow228/answers-000000000106.csv...
# Copying gs://stack-overflow228/answers-000000000107.csv...
# Copying gs://stack-overflow228/answers-000000000108.csv...
# Copying gs://stack-overflow228/answers-000000000109.csv...
# Copying gs://stack-overflow228/answers-000000000110.csv...
# Copying gs://stack-overflow228/answers-000000000111.csv...
# Copying gs://stack-overflow228/questions-000000000000.csv...
# Copying gs://stack-overflow228/questions-000000000001.csv...
# Copying gs://stack-overflow228/questions-000000000002.csv...
# Copying gs://stack-overflow228/questions-000000000003.csv...
# ...

# %%
# !gsutil -m cp \
  "gs://stack-overflow228/questions-000000000088.csv" \
  "gs://stack-overflow228/questions-000000000089.csv" \
  "gs://stack-overflow228/questions-000000000090.csv" \
  "gs://stack-overflow228/questions-000000000091.csv" \
  "gs://stack-overflow228/questions-000000000092.csv" \
  "gs://stack-overflow228/questions-000000000093.csv" \
  "gs://stack-overflow228/questions-000000000094.csv" \
  "gs://stack-overflow228/questions-000000000095.csv" \
  "gs://stack-overflow228/questions-000000000096.csv" \
  "gs://stack-overflow228/questions-000000000097.csv" \
  "gs://stack-overflow228/questions-000000000098.csv" \
  "gs://stack-overflow228/questions-000000000099.csv" \
  "gs://stack-overflow228/questions-000000000100.csv" \
  "gs://stack-overflow228/questions-000000000101.csv" \
  "gs://stack-overflow228/questions-000000000102.csv" \
  "gs://stack-overflow228/questions-000000000103.csv" \
  "gs://stack-overflow228/questions-000000000104.csv" \
  "gs://stack-overflow228/questions-000000000105.csv" \
  "gs://stack-overflow228/questions-000000000106.csv" \
  "gs://stack-overflow228/questions-000000000107.csv" \
  "gs://stack-overflow228/questions-000000000108.csv" \
  "gs://stack-overflow228/questions-000000000109.csv" \
  "gs://stack-overflow228/questions-000000000110.csv" \
  "gs://stack-overflow228/questions-000000000111.csv" \
  "gs://stack-overflow228/questions-000000000112.csv" \
  "gs://stack-overflow228/questions-000000000113.csv" \
  "gs://stack-overflow228/questions-000000000114.csv" \
  "gs://stack-overflow228/questions-000000000115.csv" \
  "gs://stack-overflow228/questions-000000000116.csv" \
  "gs://stack-overflow228/questions-000000000117.csv" \
  "gs://stack-overflow228/questions-000000000118.csv" \
  "gs://stack-overflow228/questions-000000000119.csv" \
  "gs://stack-overflow228/questions-000000000120.csv" \
  "gs://stack-overflow228/questions-000000000121.csv" \
  "gs://stack-overflow228/questions-000000000122.csv" \
  "gs://stack-overflow228/questions-000000000123.csv" \
  "gs://stack-overflow228/questions-000000000124.csv" \
  "gs://stack-overflow228/questions-000000000125.csv" \
  "gs://stack-overflow228/questions-000000000126.csv" \
  "gs://stack-overflow228/questions-000000000127.csv" \
  "gs://stack-overflow228/questions-000000000128.csv" \
  "gs://stack-overflow228/questions-000000000129.csv" \
  "gs://stack-overflow228/questions-000000000130.csv" \
  "gs://stack-overflow228/questions-000000000131.csv" \
  "gs://stack-overflow228/questions-000000000132.csv" \
  "gs://stack-overflow228/questions-000000000133.csv" \
  "gs://stack-overflow228/questions-000000000134.csv" \
  "gs://stack-overflow228/questions-000000000135.csv" \
  "gs://stack-overflow228/questions-000000000136.csv" \
  "gs://stack-overflow228/questions-000000000137.csv" \
  "gs://stack-overflow228/questions-000000000138.csv" \
  "gs://stack-overflow228/questions-000000000139.csv" \
  "gs://stack-overflow228/questions-000000000140.csv" \
  .

# %%
answers = pd.read_csv('answers-000000000000.csv')
for i in range(1, 111):
  if i < 10:
    answers.append(pd.read_csv('answers-00000000000' + str(i) + '.csv'), ignore_index=True)
  elif i > 9 and i < 100: 
    answers.append(pd.read_csv('answers-0000000000' + str(i) + '.csv'), ignore_index=True)
  elif i < 99:
    answers.append(pd.read_csv('answers-00000000' + str(i) + '.csv'), ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
questions = pd.read_csv('questions-000000000000.csv')
for i in range(1, 111):
  if i < 10:
    questions.append(pd.read_csv('questions-00000000000' + str(i) + '.csv'), ignore_index=True)
  elif i > 9 and i < 100:
    questions.append(pd.read_csv('questions-0000000000' + str(i) + '.csv'), ignore_index=True)
  elif i < 99:
    questions.append(pd.read_csv('questions-00000000' + str(i) + '.csv'), ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
questions1 = questions

# %%
# (questions1
#  .insert(0, 'code', questions1['body'].str.extractall("<pre><code>(.*?)<\/code><\/pre>", flags = re.DOTALL)
#  .rename(columns={0: 'col'})
# .reset_index().dropna()
# .reset_index().rename(columns={0: 'col'})
# .groupby('level_0')['col'].agg(','.join)
# .reset_index()['col']))

# %%
# questions1.dropna()
# questions1.head()

# %%
# len(questions1['code'])

# %%
# pd.options.display.max_colwidth = 2000
# questions1['body'][16]

# %%
import numpy as np
import pandas as pd
import re


cdata = questions[['id', 'title', 'body', 'tags']]
cdata['tags'] = questions['tags'].astype('str')
cdata.head()
mltags = '''
tensorflow

tensorflow2.0

tensorflow-gpu

tensorflow2.x

tensorflow1.15

tensorflow2

tensorflow-layers

tensorflow1.12

torch

pytorch

torchvision

torchtext

pytorch-dataloader

gpytorch

torchaudio

pytorch3d

keras

keras-2

keras-metrics

keras-rl

keras-vggface

keras-lambda

tf.keras

keras-layer

datascience

data science

ml'''
mltags = mltags.split('\n')
mltags = [tag for tag in mltags if tag != '']
mltags, len(mltags)
mask = pd.Series(-1, np.arange(len(cdata)))
for tag in mltags:
    mask = mask + cdata['tags'].str.find(tag) + 1
mask[mask >= 0] = 1
mask[mask < 0] = 0
mask = mask.astype('bool')
questions = cdata[mask]
# questions.drop(columns=["parent_id"], inplace=True)
questions.rename(columns={"id" : "parent_id", "body" : "questions"}, inplace=True)
answers.rename(columns={"body" : "answers"}, inplace=True)
qa = questions.merge(answers, on=['parent_id'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
(qa
 .insert(0, 'code', qa['questions'].str.extractall("<pre><code>(.*?)<\/code><\/pre>", flags = re.DOTALL)
 .rename(columns={0: 'col'})
.reset_index().dropna()
.reset_index().rename(columns={0: 'col'})
.groupby('level_0')['col'].agg(','.join)
.reset_index()['col']))

# %%
# qa.to_csv('drive/MyDrive/QA.csv')

# %%
qa.head()
# Out:
#                                                 code  ...  view_count
# 0  15:59:27.406     1&gt;Target &quot;ResolvedXDC...  ...         NaN
# 1                         $ pip install tensornets\n  ...         NaN
# 2  P indicates the period (required)\nnY indicate...  ...         NaN
# 3  t_a = tf.TensorArray(dtype=tf.float32,size=0,d...  ...         NaN
# 4  static List xmlList = [];\n    List filePathLi...  ...         NaN
#
# [5 rows x 24 columns]

# %%
qa.columns
# Out:
# Index(['code', 'parent_id', 'title_x', 'questions', 'tags_x', 'id', 'title_y',
#        'answers', 'accepted_answer_id', 'answer_count', 'comment_count',
#        'community_owned_date', 'creation_date', 'favorite_count',
#        'last_activity_date', 'last_edit_date', 'last_editor_display_name',
#        'last_editor_user_id', 'owner_display_name', 'owner_user_id',
#        'post_type_id', 'score', 'tags_y', 'view_count'],
#       dtype='object')

# %%
col = qa.columns
for i in col:
  if i != 'answers' and i != 'code':
    qa.drop(columns=[i], inplace=True)

# %%
qa.head()
# Out:
#                                                 code                                            answers
# 0  15:59:27.406     1&gt;Target &quot;ResolvedXDC...  <p><a href="https://ewsoftware.github.io/XMLCo...
# 1                         $ pip install tensornets\n  <p><a href="https://docs.codeclimate.com/docs/...
# 2  P indicates the period (required)\nnY indicate...  <p>The problem was in the gcc compiler\nI foll...
# 3  t_a = tf.TensorArray(dtype=tf.float32,size=0,d...  <p>You'll find the answer at</p>\n<p><a href="...
# 4  static List xmlList = [];\n    List filePathLi...  <p>You can clear the value by making <code>cle...

# %%
qa.to_csv('drive/MyDrive/QA.csv')
